# %%
from google import genai
from google.genai import types

# %%
client=genai.Client(
    vertexai=True,
    project="empyrean-aurora-469815-n4",
    location="us-west1",
    http_options=types.HttpOptions(api_version="v1")
)

# %%
query="Explain the difference between machine learning and deep learning in 2 sentences."
model="gemini-2.5-flash"

response = client.models.generate_content(
    model=model,
    contents=query
)
print(response.text)
# Out:
# Machine learning is a broad field allowing systems to learn from data to make predictions or decisions. Deep learning is a specialized subfield of machine learning that uses multi-layered neural networks to automatically extract complex features directly from raw data, often performing feature engineering on its own.
